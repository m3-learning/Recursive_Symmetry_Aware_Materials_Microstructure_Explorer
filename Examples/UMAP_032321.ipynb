# %% [markdown]
# # 1. Load packages
# ## Install Package

# %%
# !pip install Recursive_Symmetry_Aware_Materials_Microstructure_Explorer
# Out:
# Collecting git+https://github.com/Joeclinton1/google-images-download.git
#   Cloning https://github.com/Joeclinton1/google-images-download.git to /private/var/folders/np/hwhg0jcx7zz9x0zw92qd4rb00000gn/T/pip-req-build-tlygat40
# Requirement already satisfied (use --upgrade to upgrade): google-images-download==2.8.0 from git+https://github.com/Joeclinton1/google-images-download.git in /Users/joshuaagar/opt/anaconda3/lib/python3.8/site-packages
# Requirement already satisfied: selenium in /Users/joshuaagar/opt/anaconda3/lib/python3.8/site-packages (from google-images-download==2.8.0) (3.141.0)
# Requirement already satisfied: urllib3 in /Users/joshuaagar/.local/lib/python3.8/site-packages (from selenium->google-images-download==2.8.0) (1.26.4)
# Building wheels for collected packages: google-images-download
#   Building wheel for google-images-download (setup.py) ... done
#   Created wheel for google-images-download: filename=google_images_download-2.8.0-py2.py3-none-any.whl size=15503 sha256=9a1ac5b8e55913dee1b3accca87e20f9fbbbf685dc3319d681b7efc1cf3bdca1
#   Stored in directory: /private/var/folders/np/hwhg0jcx7zz9x0zw92qd4rb00000gn/T/pip-ephem-wheel-cache-bcxrbkyb/wheels/50/f1/1c/089cebf505dc8e8f87f61a21a439652bc53e39ebb2c3f6767e
# Successfully built google-images-download

# %% [markdown]
# ## Import Packages

# %%
import torchvision.transforms as transforms
import torch
from torch.utils.data import DataLoader, Dataset
import numpy as np
import matplotlib.pyplot as plt
import Recursive_Symmetry_Aware_Materials_Microstructure_Explorer.util as util
import Recursive_Symmetry_Aware_Materials_Microstructure_Explorer.select_model as select_model
import Recursive_Symmetry_Aware_Materials_Microstructure_Explorer.viz as viz
import umap.umap_ as umap
import time

# %% [markdown]
# # 2. Downloading Images
# Since this example is just a demo we will download images from google. We have selected a few materials catagories but you can use whatever catagories you like. You can also use your own images.

# %%
# Folder where files will be downloaded
path = './downloads/'

# Names of catagories to download
names = ['transmission electron microscopy', 'atomic force microscopy', 'optical microscopy', 'metals',
        'ceramics', 'polymers','semiconductors']


util.image_scraping.download_images_from_google(names, path)
# Out:
# Item no.: 1 --> Item name = transmission electron microscopy
# Evaluating...
# Starting Download...
# Image URL: https://www.ccber.ucsb.edu/sites/default/files/Electron_Microscope.jpg
# Completed Image ====> 1.electron_microscope.jpg
# Image URL: https://warwick.ac.uk/fac/sci/physics/current/postgraduate/regs/mpagswarwick/ex5/techniques/structural/tem/tem_ed.jpg
# Completed Image ====> 2.tem_ed.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/e/ee/STEM_fig.png/1200px-STEM_fig.png
# Completed Image ====> 3.1200px-stem_fig.png
# Image URL: https://cdn.britannica.com/90/113690-004-CB552E7F/Transmission-electron-microscope.jpg
# Completed Image ====> 4.transmission-electron-microscope.jpg
# Image URL: https://www.news-medical.net/image.axd?picture=TEM%20schwann%20cell%20-%20Jose%20Luis%20Calvo%20_thumb%5B8%5D_thumb.jpg
# Completed Image ====> 5.image.axd.jpg
# Image URL: https://www.biosciencenotes.com/wp-content/uploads/2018/06/TEM6.jpg
# Completed Image ====> 6.tem6.jpg
# Image URL: https://i.ytimg.com/vi/D3JY4LgyX6Q/hqdefault.jpg
# Completed Image ====> 7.hqdefault.jpg
# Image URL: https://www.researchgate.net/profile/Naresh-Marturi/publication/281534044/figure/fig5/AS:614167945961502@1523440457682/Transmission-electron-microscope-schematic-diagram.png
# Completed Image ====> 8.transmission-electron-microscope-schematic-diagram.png
# Image URL: https://ars.els-cdn.com/content/image/3-s2.0-B978008100040300002X-f02-08-9780081000403.jpg
# Completed Image ====> 9.3-s2.0-b978008100040300002x-f02-08-9780081000403.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/2/22/Schematic_wiki2.jpg/424px-Schematic_wiki2.jpg
# Completed Image ====> 10.424px-schematic_wiki2.jpg
# Image URL: https://cdn.technologynetworks.com/tn/images/body/012-semvstem-021582637719773.jpg
# Completed Image ====> 11.012-semvstem-021582637719773.jpg
# Image URL: http://bitesizebio.s3.amazonaws.com/wp-content/uploads/2016/07/08150412/Fig1.jpg
# Completed Image ====> 12.fig1.jpg
# Image URL: https://www.acsmaterial.com/pub/media/wysiwyg/TEM-1.jpg
# Completed Image ====> 13.tem-1.jpg
# Image URL: https://media.springernature.com/original/springer-static/image/chp%3A10.1007%2F978-4-431-56502-4_2/MediaObjects/321705_1_En_2_Fig1_HTML.gif
# Completed Image ====> 14.321705_1_en_2_fig1_html.gif
# Image URL: https://www.hitachi-hightech.com/products/images/11926/em-hf3300_main.png
# Completed Image ====> 15.em-hf3300_main.png.webp
# Image URL: https://static.cambridge.org/binary/version/id/urn:cambridge.org:id:binary-alt:20190705072758-13713-mediumThumb-07033fig7_1.jpg?pub-status=live
# Completed Image ====> 16.urn:cambridge.org:id:binary-alt:20190705072758-13713-mediumthumb-07033fig7_1.jpg
# Image URL: https://www.ccber.ucsb.edu/sites/default/files/Gossypium_JT.jpg
# Completed Image ====> 17.gossypium_jt.jpg
# Image URL: https://ysjournal.com/wp-content/uploads/2015/09/Transmission-Electron-Microscope.jpg
# Completed Image ====> 18.transmission-electron-microscope.jpg
# Image URL: http://nanofase.eu/showimg.php?filename=m1000_1452.jpg
# Completed Image ====> 19.showimg.php.jpg
# Image URL: https://cdn.britannica.com/s:300x169,c:crop/90/113690-004-CB552E7F/Transmission-electron-microscope.jpg
# Completed Image ====> 20.transmission-electron-microscope.jpg
# Image URL: https://myscope.training/myscope/images/tem/tem_interaction.png
# Completed Image ====> 21.tem_interaction.png
# Image URL: https://www.news-medical.net/image.axd?picture=2018%2F1%2FTEM_-_full.jpg
# Completed Image ====> 22.image.axd.jpg
# Image URL: https://www.unl.edu/ncmn-cfem/xzli/em/tem2.gif
# Completed Image ====> 23.tem2.gif
# Image URL: https://www.researchgate.net/profile/Rubens-Queiroz/publication/331635800/figure/fig2/AS:758097853296644@1557756021842/Scanning-electron-microscopy-SEM-and-transmission-electron-microscopy-TEM-of.jpg
# Completed Image ====> 24.scanning-electron-microscopy-sem-and-transmission-electron-microscopy-tem-of.jpg.png
# Image URL: https://jiam.utk.edu/wp-content/uploads/sites/284/2020/10/Zeiss-Libra.jpg
# Completed Image ====> 25.zeiss-libra.jpg
#
# Errors: 0
#
#
# Item no.: 2 --> Item name = atomic force microscopy
# Evaluating...
# Starting Download...
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/7/7c/
# Image URL: http://biofisica.info/wp-content/uploads/2018/01/f1.png
# Completed Image ====> 16.f1.png
# Image URL: https://ars.els-cdn.com/content/image/1-s2.0-S0013468619323448-egi109GK228MT1.jpg
# Completed Image ====> 17.1-s2.0-s0013468619323448-egi109gk228mt1.jpg
# Image URL: https://images.squarespace-cdn.com/content/v1/571e6fbb01dbae8818af9ed5/1545054680653-9SCY2ANFYBVFA1MTS8KE/ke17ZwdGBToddI8pDm48kKtKYAnJw-wEuo2e6sYw71Z7gQa3H78H3Y0txjaiv_0fDoOvxcdMmMKkDsyUqMSsMWxHk725yiiHCCLfrh8O1z5QPOohDIaIeljMHgDF5CVlOqpeNLcJ80NK65_fV7S1UQEEMarB47705nZrJF8_h6lcNVNRoLAVInTmO84tVSHWZtJ3qR9G2BYeA0wOAaeYNg/AFM+of+brain+abscess+tissue.png
# Completed Image ====> 18.afm+of+brain+abscess+tissue.png
# Image URL: https://acs-h.assetsadobe.com/is/image//content/dam/cen/96/16/09616-leadcon-combo-update.jpg/?$responsive$&wid=700&qlt=90,0&resMode=sharp2
# Completed Image ====> 19..jpg
# Image URL: https://media.springernature.com/lw785/springer-static/image/prt%3A978-0-387-92897-5%2F1/MediaObjects/978-0-387-92897-5_1_Part_Fig1-1213_HTML.gif
# Completed Image ====> 20.978-0-387-92897-5_1_part_fig1-1213_html.gif.png
# Image URL: https://static.physikinstrumente.com/fileadmin/_processed_/9/4/csm_Modular_designed_microscopy_1cdb8982b5.jpg
# Completed Image ====> 21.csm_modular_designed_microscopy_1cdb8982b5.jpg
# Image URL: https://ars.els-cdn.com/content/image/1-s2.0-S0030401817303887-fx1.jpg
# Completed Image ====> 22.1-s2.0-s0030401817303887-fx1.jpg
# Image URL: https://www.bruker.com/en/products-and-solutions/microscopes/materials-afm/dimension-icon-afm/_jcr_content/teaserImage.coreimg.png/1600244130328/dimension-icon-atomic-force-microscope-bruker.png
# Completed Image ====> 23.dimension-icon-atomic-force-microscope-bruker.png
# Image URL: https://d1otjdv2bf0507.cloudfront.net/images/Article_Images/ImageForArticle_5634_1611208885733452.png
# Completed Image ====> 24.imageforarticle_5634_1611208885733452.png
# Image URL: https://www.researchgate.net/publication/319412312/figure/fig1/AS:533613181247488@1504234704587/Scheme-1-Schematic-illustration-of-in-situ-atomic-force-microscopy-AFM-The-AFM-tip-is.png
# Completed Image ====> 25.scheme-1-schematic-illustration-of-in-situ-atomic-force-microscopy-afm-the-afm-tip-is.png
#
# Errors: 2
#
#
# Item no.: 3 --> Item name = optical microscopy
# Evaluating...
# Starting Download...
# Image URL: https://ars.els-cdn.com/content/image/3-s2.0-B9780081005521000087-f08-02-9780081005521.jpg
# Completed Image ====> 1.3-s2.0-b9780081005521000087-f08-02-9780081005521.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Microscope_compound_diagram.png/150px-Microscope_compound_diagram.png
# Completed Image ====> 2.150px-microscope_compound_diagram.png
# Image URL: https://ars.els-cdn.com/content/image/3-s2.0-B9780323264358000046-f04-03-9780323264358.jpg
# Completed Image ====> 3.3-s2.0-b9780323264358000046-f04-03-9780323264358.jpg
# Image URL: https://www.photonics.com/images/Web/Articles/2011/12/1/thumbnail_49296.jpg
# Completed Image ====> 4.thumbnail_49296.jpg
# Image URL: https://res.cloudinary.com/dk-find-out/image/upload/q_80,w_1920,f_auto/MA_00054029_yhcq4u.jpg
# Completed Image ====> 5.ma_00054029_yhcq4u.jpg
# Image URL: https://jordilabs.com/wp-content/uploads/2017/10/tlm-499x400.png
# Completed Image ====> 6.tlm-499x400.png
# Image URL: https://mmegias.webs.uvigo.es/02-english/6-tecnicas/imagenes/6-microscopio.png
# Completed Image ====> 7.6-microscopio.png
# Image URL: https://www.edmundoptics.com/contentassets/4dbf8d164b0e4da3adff186990402f4c/fig-2-df.gif
# Completed Image ====> 8.fig-2-df.gif
# Image URL: https://www.edmundoptics.com/contentassets/5477dc44fffb48a78b2d684a0fbc9832/fig-2-fl.gif
# Completed Image ====> 9.fig-2-fl.gif
# Image URL: http://www.icbl.hw.ac.uk/learnem/doitpoms/OpticalMicroscopy/images/trans-microscope.jpg
# Completed Image ====> 10.trans-microscope.jpg
# Image URL: https://www.tedpella.com/mscope_html/22460-10.jpg
# Completed Image ====> 11.22460-10.jpg
# Image URL: https://micro.magnet.fsu.edu/primer/techniques/polarized/images/polmicroalignmentfigure1.jpg
# Completed Image ====> 12.polmicroalignmentfigure1.jpg
# Image URL: https://www.researchgate.net/profile/Martin-Wiklund-3/publication/230632501/figure/fig1/AS:300648693288960@1448691642222/Schematic-of-a-wide-field-optical-microscope-including-an-illustration-of-light-rays-from.png
# Completed Image ====> 13.schematic-of-a-wide-field-optical-microscope-including-an-illustration-of-light-rays-from.png
# Image URL: https://www.news-medical.net/image.axd?picture=2017%2F4%2FLaboratory_light_microscope_680x_-_science_photo.jpg
# Completed Image ====> 14.image.axd.jpg
# Image URL: https://d12oja0ew7x0i8.cloudfront.net/images/Article_Images/ImageForArticle_12817(1).jpg
# Completed Image ====> 15.imageforarticle_12817(1).jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Microscope_simple_diagram.png/150px-Microscope_simple_diagram.png
# Completed Image ====> 16.150px-microscope_simple_diagram.png
# Image URL: https://d2c0zrx8qw0prh.cloudfront.net/images/Article_Images/ImageForArticle_1488(1).jpg
# Completed Image ====> 17.imageforarticle_1488(1).jpg
# Image URL: https://physicsworld.com/wp-content/uploads/2020/10/Figure1.png
# Completed Image ====> 18.figure1.png
# Image URL: https://www.ntmdt-si.com/data/media/images/spm_basics/scanning_optical_microscopy/classical_optical_microscopy/img01.gif
# Completed Image ====> 19.img01.gif
# Image URL: https://ares.jsc.nasa.gov/_pictures/_laboratories/optical-microscopy.png
# Completed Image ====> 20.optical-microscopy.png
# Image URL: https://static4.olympus-ims.com/data/Image/IM/OpticalMicroscopes/19-03zu.gif?rev=4C0A
# Completed Image ====> 21.19-03zu.gif
# Image URL: https://www.researchgate.net/publication/321771038/figure/fig1/AS:574546050809856@1513993861995/a-Schematic-presentation-of-the-optical-microscopy-setup-Polarized-light-is-focused-on.png
# Completed Image ====> 22.a-schematic-presentation-of-the-optical-microscopy-setup-polarized-light-is-focused-on.png
# Image URL: https://www.biotek.com/assets/tech_resources/12611/figure10.jpg
# Completed Image ====> 23.figure10.jpg
# Image URL: http://zeiss-campus.magnet.fsu.edu/articles/basics/images/reflectedfigure6.jpg
# Completed Image ====> 24.reflectedfigure6.jpg
# Image URL: https://i.ytimg.com/vi/S7Ysd7DnVGU/maxresdefault.jpg
# Completed Image ====> 25.maxresdefault.jpg
#
# Errors: 0
#
#
# Item no.: 4 --> Item name = metals
# Evaluating...
# Starting Download...
# Image URL: https://themonticellonews.com/clients/themonticellonews/1-20-2021-1-14-55-PM-10271813.jpg
# Completed Image ====> 1.1-20-2021-1-14-55-pm-10271813.jpg
# Image URL: https://cdn.mos.cms.futurecdn.net/ny4mavbUh8k6fpupcYdmg5.jpg
# Completed Image ====> 2.ny4mavbuh8k6fpupcydmg5.jpg
# Image URL: https://www.bruker.com/en/applications/industrial/metals/_jcr_content/root/overviewstage/desktopImage.coreimg.82.1920.jpeg/1600196225614/metal-tubes.jpeg
# Completed Image ====> 3.metal-tubes.jpeg
# Image URL: https://www.tutorialspoint.com/chemistry_part1/images/solid_metal.jpg
# Completed Image ====> 4.solid_metal.jpg
# Image URL: https://malvern.dist.sdlmedia.com/distributions/?o=07a8409c-6f3d-4d27-adf4-e36377ef3f92?qualitylevel=60&width=1920
# Completed Image ====> 5.?o=07a8409c-6f3d-4d27-adf4-e36377ef3f92.jpg
# Image URL: https://www.thoughtco.com/thmb/m7tJHuSejWd7VHyo3MslyD87Gh8=/3235x2426/smart/filters:no_upscale()/GettyImages-139821357-82a2f5a1a16f4d76aea74236de88158b.jpg
# Completed Image ====> 6.gettyimages-139821357-82a2f5a1a16f4d76aea74236de88158b.jpg
# Image URL: https://responsive.fxempire.com/cover/615x410/_n/_fxempire_/2019/07/Metals.jpg
# Completed Image ====> 7.metals.jpg
# Image URL: https://www.texasironandmetal.com/wp-content/uploads/2020/08/TIM_blog_metal_types.jpg
# Completed Image ====> 8.tim_blog_metal_types.jpg
# Image URL: https://recyclinginside.com/wp-content/uploads//sites/3/2019/03/recycled-metals.jpg
# Completed Image ====> 9.recycled-metals.jpg
# Image URL: https://web-assets.bcg.com/dims4/default/7b3e5a6/2147483647/strip/true/crop/1694x889+0+30/resize/1200x630!/quality/90/?url=http%3A%2F%2Fboston-consulting-group-brightspot.s3.amazonaws.com%2F67%2F26%2F0fc72e3ed704284cef43890cd244%2Fwef-mining-and-metals-sept2015-1694x950-tcm9-59542.jpg
# Completed Image ====> 10..jpg
# Image URL: https://rjofutures.rjobrien.com/assets/images/metals.jpg
# Completed Image ====> 11.metals.jpg
# Image URL: https://olddungeonmaster.files.wordpress.com/2016/12/metals.jpg
# Completed Image ====> 12.metals.jpg
# Image URL: https://useruploads.socratic.org/hKwbtiIyQmaM5bE63WNP_Metals.jpg
# Completed Image ====> 13.hkwbtiiyqmam5be63wnp_metals.jpg
# Image URL: https://sciencenotes.org/wp-content/uploads/2020/08/Metals-vs-Nonmetals-scaled.jpg
# Completed Image ====> 14.metals-vs-nonmetals-scaled.jpg
# Completed Image ====> 9.polymer-molecule-777x518.jpg
# Image URL: https://img.jagranjosh.com/imported/images/E/GK/What-are-Polymers.png
# Completed Image ====> 10.what-are-polymers.png
# Image URL: https://cdn.britannica.com/98/128798-050-1636D763/formation-nylon-polymer.jpg
# Completed Image ====> 11.formation-nylon-polymer.jpg
# Image URL: https://augustrs.com/wp-content/uploads/2020/02/Polymer-Chain_1.jpg
# Completed Image ====> 12.polymer-chain_1.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Polyacetylene-3D-balls.png/1200px-Polyacetylene-3D-balls.png
# Completed Image ====> 13.1200px-polyacetylene-3d-balls.png
# Image URL: http://www.ilpi.com/msds/ref/gifs/polyethylene.jpg
# Completed Image ====> 14.polyethylene.jpg
# Image URL: https://www.thoughtco.com/thmb/qYGJxA9_Pp8mtMzX5G0K6qBBmY4=/768x0/filters:no_upscale():max_bytes(150000):strip_icc()/three-dimensional-model-of-polyvinyl-chloride-165874889-5c425ea7c9e77c000188be6d.jpg
# Completed Image ====> 15.three-dimensional-model-of-polyvinyl-chloride-165874889-5c425ea7c9e77c000188be6d.jpg
# Image URL: https://d12oja0ew7x0i8.cloudfront.net/images/Article_Images/ImageForArticle_18412(1).jpg
# Completed Image ====> 16.imageforarticle_18412(1).jpg
# Image URL: https://www2.chemistry.msu.edu/faculty/reusch/virttxtjml/Images2/blocpoly.gif
# Completed Image ====> 17.blocpoly.gif
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/7/77/Polymerization_classification_ENmod.png/440px-Polymerization_classification_ENmod.png
# Completed Image ====> 18.440px-polymerization_classification_enmod.png
# Image URL: https://www.neles.com/siteassets/industry-images/valves-industry-pages/chemical-industry/valves-for-polyolefins-and-polymers/valves-for-polyolefins-and-polymers.jpg?preset=preset_1920x640_align_center
# Completed Image ====> 19.valves-for-polyolefins-and-polymers.jpg
# Image URL: https://slideplayer.com/7037541/24/images/slide_1.jpg
# Completed Image ====> 20.slide_1.jpg
# Image URL: https://i.ytimg.com/vi/EP0zfm_FVqc/maxresdefault.jpg
# Completed Image ====> 21.maxresdefault.jpg
# Image URL: https://www.science.org.au/curious/sites/default/files/images/everything-else/polymers/Image10.png
# Completed Image ====> 22.image10.png
# Image URL: https://www.rspinc.com/wp-content/uploads/2019/10/poly-vs-plastic.jpg
# Completed Image ====> 23.poly-vs-plastic.jpg
# Image URL: https://www.thermofisher.com/blog/materials/wp-content/uploads/sites/7/2019/09/polymers2-1.png
# Completed Image ====> 24.polymers2-1.png.webp
# Image URL: https://www.agilent.com/cs/publishingimages/polymers_plastics_1280x364.jpg
# Completed Image ====> 25.polymers_plastics_1280x364.jpg.webp
#
# Errors: 0
#
#
# Item no.: 7 --> Item name = semiconductors
# Evaluating...
# Starting Download...
# Image URL: https://base.imgix.net/files/base/ebm/industryweek/image/2019/05/industryweek_28143_11__semiconductors_and_other_electronic_components_0.png?auto=format&fit=max&w=1200
# Completed Image ====> 1.industryweek_28143_11__semiconductors_and_other_electronic_components_0.png
# Image URL: https://www.iqsdirectory.com/resources/wp-content/uploads/2019/01/semiconductors1.jpg
# Completed Image ====> 2.semiconductors1.jpg
# Image URL: https://g.foolcdn.com/editorial/images/622993/semiconductor_CmxpJRc.jpg
# Completed Image ====> 3.semiconductor_cmxpjrc.jpg
# Image URL: https://www.ul.com/sites/g/files/qbfpbp251/files/styles/hero_boxed_width/public/2019-05/Image50-SemiconductorSD-Musary-022619-Hero-1000x715.jpg?itok=zwag2lFY
# Completed Image ====> 4.image50-semiconductorsd-musary-022619-hero-1000x715.jpg
# Image URL: https://img.etimg.com/thumb/msid-82191385,width-650,imgsize-189528,,resizemode-4,quality-100/istock-1141230722.jpg
# Completed Image ====> 5.istock-1141230722.jpg
# Image URL: https://mk0logisticsoftiiud5.kinstacdn.com/wp-content/uploads/2019/10/Article-Key-Image-1236723382-800x420.jpg
# Completed Image ====> 6.article-key-image-1236723382-800x420.jpg
# Image URL: https://www.brinknews.com/wp-content/uploads/2019/11/shutterstock_458703433.jpg
# Completed Image ====> 7.shutterstock_458703433.jpg
# Image URL: https://penntoday.upenn.edu/sites/default/files/2021-03/iStock-1221138143.jpg
# Completed Image ====> 8.istock-1221138143.jpg
# Image URL: https://www.merckgroup.com/content/dam/web/corporate/images/business-specific/performance-materials/global/Semiconductors-promotional-800x600.jpg
# Completed Image ====> 9.semiconductors-promotional-800x600.jpg.webp
# Image URL: https://cdn1.vogel.de/unsafe/800x0/smart/images.vogel.de/vogelonline/bdb/1675100/1675109/original.jpg
# Completed Image ====> 10.original.jpg
# Image URL: https://images.mktw.net/im-324961?width=620&size=1.4382022471910112
# Completed Image ====> 11.im-324961.jpg
# Image URL: https://www.electronicshub.org/wp-content/uploads/2019/03/Types-of-Semiconductor-Devices-Featured-Image.jpg
# Completed Image ====> 12.types-of-semiconductor-devices-featured-image.jpg
# Image URL: https://www.computerhope.com/jargon/s/semicond.jpg
# Completed Image ====> 13.semicond.jpg
# Image URL: https://d10lvax23vl53t.cloudfront.net/images/Article_Images/ImageForArticle_1624(1).jpg
# Completed Image ====> 14.imageforarticle_1624(1).jpg
# Image URL: https://www.verdict.co.uk/wp-content/uploads/2019/02/semiconductor.jpg
# Completed Image ====> 15.semiconductor.jpg
# Image URL: https://www.quest-global.com/wp-content/uploads/2020/01/semiconductor.jpg
# Completed Image ====> 16.semiconductor.jpg
# Image URL: https://www.theengineeringprojects.com/wp-content/uploads/2020/08/Semiconductor-1.jpg
# Completed Image ====> 17.semiconductor-1.jpg
# Image URL: https://analyticsinsight.b-cdn.net/wp-content/uploads/2020/11/Semiconductor-1024x684.jpg
# Completed Image ====> 18.semiconductor-1024x684.jpg
# Image URL: https://bryantarchway.com/wp-content/uploads/2016/12/processor1.jpg
# Completed Image ====> 19.processor1.jpg
# Image URL: https://www.semiconductors.org/wp-content/uploads/2018/09/quantum.png
# Completed Image ====> 20.quantum.png
# Image URL: https://www.etftrends.com/wp-content/uploads/2021/04/Leveraged-Bulls-Arent-Hopping-Off-the-Semiconductors-Train.jpg
# Completed Image ====> 21.leveraged-bulls-arent-hopping-off-the-semiconductors-train.jpg
# Image URL: https://d1af89beukha9h.cloudfront.net/wp-content/uploads/2020/07/Semiconductor-manufacturers-1024x656.jpg
# Completed Image ====> 22.semiconductor-manufacturers-1024x656.jpg
# Image URL: https://www.hitachi-hightech.com/image/global/products/device/semiconductor/history_il01.gif
# Completed Image ====> 23.history_il01.gif
# Image URL: https://www.mckinsey.com/~/media/McKinsey/Industries/Semiconductors/Our%20Insights/Coronavirus%20Implications%20for%20the%20semiconductor%20industry/Semiconductors-coronavirus-implications-STANDARD-1536x1536.jpg
# Completed Image ====> 24.semiconductors-coronavirus-implications-standard-1536x1536.jpg
# Image URL: https://www.electronicsmedia.info/wp-content/uploads/2020/02/Semiconductors.png
# Completed Image ====> 25.semiconductors.png
#
# Errors: 0
#
#
# Item no.: 8 --> Item name =
# Evaluating...
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Expecting value: line 1 column 1 (char 0)
# Image objects data unpacking failed. Please leave a comment with the above error at https://github.com/hardikvasa/google-images-download/pull/298
# Traceback (most recent call last):
#   File "/Users/joshuaagar/opt/anaconda3/lib/python3.8/site-packages/google_images_download/google_images_download.py", line 234, in download_page
#     return self._image_objects_from_pack(self._extract_data_pack(respData)), self.get_all_tabs(respData)
#   File "/Users/joshuaagar/opt/anaconda3/lib/python3.8/site-packages/google_images_download/google_images_download.py", line 199, in _image_objects_from_pack
#     image_objects = json.loads(data)[31][0][12][2]
#   File "/Users/joshuaagar/opt/anaconda3/lib/python3.8/json/__init__.py", line 357, in loads
#     return _default_decoder.decode(s)
#   File "/Users/joshuaagar/opt/anaconda3/lib/python3.8/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/Users/joshuaagar/opt/anaconda3/lib/python3.8/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/joshuaagar/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-727412b88dbb>", line 9, in <module>
#     util.image_scraping.download_images_from_google(names, path)
#   File "/Volumes/GoogleDrive/My Drive/codes/Recursive_Symmetry_Aware_Materials_Microstructure_Explorer/src/Recursive_Symmetry_Aware_Materials_Microstructure_Explorer/util/image_scraping.py", line 17, in download_images_from_google
#     paths = response.download(arguments)
#   File "/Users/joshuaagar/opt/anaconda3/lib/python3.8/site-packages/google_images_download/google_images_download.py", line 952, in download
#     paths, errors = self.download_executor(arguments)
#   File "/Users/joshuaagar/opt/anaconda3/lib/python3.8/site-packages/google_images_download/google_images_download.py", line 1077, in download_executor
#     images, tabs = self.download_page(url)  # download page
#   File "/Users/joshuaagar/opt/anaconda3/lib/python3.8/site-packages/google_images_download/google_images_download.py", line 238, in download_page
#     sys.exit()
# SystemExit
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/joshuaagar/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/joshuaagar/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/joshuaagar/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/joshuaagar/opt/anaconda3/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/google_images_download/google_images_download.py in download_page(self, url)
#     233         try:
# --> 234             return self._image_objects_from_pack(self._extract_data_pack(respData)), self.get_all_tabs(respData)
#     235         except Exception as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/google_images_download/google_images_download.py in _image_objects_from_pack(self, data)
#     198     def _image_objects_from_pack(self, data):
# --> 199         image_objects = json.loads(data)[31][0][12][2]
#     200         image_objects = [x for x in image_objects if x[0] == 1]
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-3-727412b88dbb> in <module>
#       8
# ----> 9 util.image_scraping.download_images_from_google(names, path)
#
# /Volumes/GoogleDrive/My Drive/codes/Recursive_Symmetry_Aware_Materials_Microstructure_Explorer/src/Recursive_Symmetry_Aware_Materials_Microstructure_Explorer/util/image_scraping.py in download_images_from_google(names, path, num, verbose)
#      16     # passing the arguments to the function
# ---> 17     paths = response.download(arguments)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/google_images_download/google_images_download.py in download(self, arguments)
#     951             else:
# --> 952                 paths, errors = self.download_executor(arguments)
#     953                 for i in paths:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/google_images_download/google_images_download.py in download_executor(self, arguments)
#    1076                     if limit < 101:
# -> 1077                         images, tabs = self.download_page(url)  # download page
#    1078                     else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/google_images_download/google_images_download.py in download_page(self, url)
#     237             print('Image objects data unpacking failed. Please leave a comment with the above error at https://github.com/hardikvasa/google-images-download/pull/298')
# --> 238             sys.exit()
#     239
#
# SystemExit:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2036                     stb = ['An exception has occurred, use %tb to see '
#    2037                            'the full traceback.\n']
# -> 2038                     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2039                                                                      value))
#    2040                 else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     821         value : exception value
#     822         """
# --> 823         return ListTB.structured_traceback(self, etype, value)
#     824
#     825     def show_exception_only(self, etype, evalue):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     696             chained_exceptions_tb_offset = 0
#     697             out_list = (
# --> 698                 self.structured_traceback(
#     699                     etype, evalue, (etb, chained_exc_ids),
#     700                     chained_exceptions_tb_offset, context)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434         else:
#    1435             self.tb = tb
# -> 1436         return FormattedTB.structured_traceback(
#    1437             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1438
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334         if mode in self.verbose_modes:
#    1335             # Verbose modes need a full traceback
# -> 1336             return VerboseTB.structured_traceback(
#    1337                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1338             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191         """Return a nice text document describing the traceback."""
#    1192
# -> 1193         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1194                                                                tb_offset)
#    1195
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1149
#    1150
# -> 1151         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1152
#    1153         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
path = './downloads/'
images, dir_jpg, name_all, dir_name = util.image_collation.image_collection(path)

# %%
# way to deal with gray images. 
transform = transforms.Compose([
            transforms.Resize((224,224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
            ])

# way to deal with gray images. 
viz_trans = transforms.Compose([
            transforms.Resize((224,224)),
            transforms.ToTensor(),
            ])

# %%
batch_size = 5
cropped_dataset = util.image_collation.image_dataset(images=images, transform=transform, viz=viz_trans)
train_dl = DataLoader(cropped_dataset, batch_size, shuffle=False, num_workers=0, pin_memory=True)

# %%
# Visualize a random input into the neural network
# Note the input into the neural network has been scaled

ind = np.random.randint(0,len(cropped_dataset))
plt.imshow(np.fliplr(np.rot90(torch.transpose(cropped_dataset.__getitem__(ind),0,2),k=3)))

# %%
# Set the parameters and CUDA, CPU useage
# Make this into a function

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# Parameters
params = {'batch_size': 64,
          'shuffle': True,
          'num_workers': 6}

# %% [markdown]
# # Create the Function that allows users to select the model as feature extractor (VGG16, ResNet34, or both)

# %%
#TODO add verbose
# TODO add tqmd
test_vgg = select_model.select_model(train_dl, 5,
                                     images, model_type='vgg',
                                     N_EPOCHS=5)

# %% [markdown]
# ## 5. Plot UMAP

# %% [markdown]
# # 6. Run UMAP

# %%
#Save the images data for UMAP plotting later

images =[]
for i in range(len(cropped_dataset)):
    images.append(torch.transpose(cropped_dataset.__getitemviz__(i),0,2).detach().numpy())

images = np.array(images)

# %%
np.save('Data_images.npy',images) #save images
np.save('Data_name_all.npy',name_all) # saves the files with the names

# %%
np.save('Data_activations.npy',test_vgg) #save activations

# %%
# !pip install umap-learn

# %%
# Calcualte UMAP activations


start = time.time()
print("Computing UMAP embedding")
np.random.seed(42)
X_umap = umap.UMAP(n_neighbors=5, min_dist=0.3,
                   n_components=2, metric='correlation').fit_transform(test_vgg)
    
# plot_embedding(X_umap, 1000, images, 'UMAP embedding of' +' {} '.format(X_umap.shape[0]) +'images'+" (1000 images shown)")
    #plt.savefig(filename, bbox_inches='tight', dpi=300)
# plot_embedding(X_umap, X_umap.shape[0], 10, images)    
stop = time.time() #end the timer

print(stop-start)

# %%
# Plot UMAP
viz.plot_embedding(X_umap, 100, 5, images*255)

# %%
np.save('Data_umap.npy', X_umap) #save UMAP activations
